# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8df26fd4ce8ebedafa9c7bed0428a977

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_dscript = city_weather["weather"][0]["description"]
        

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_dscript})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | manokwari
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | satana
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | atar
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | nishihara
# Processing Record 17 of Set 1 | norman wells
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | padang
# Processing Record 20 of Set 1 | aklavik
# Processing Record 21 of Set 1 | chitral
# Processing Record 22 of Set 1 | kahului
# Processing Record 23 of Set 1 | kapustin yar
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | dali
# Processing Record 26 of Set 1 | mantamados
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | port-gentil
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | epe
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | birao
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | saint john
# Processing Record 41 of Set 1 | praia da vitoria
# Processing Record 42 of Set 1 | abu dhabi
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | husavik
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | nouadhibou
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | chernigovka
# Processing Record 50 of Set 1 | san quintin
# Processing Record 1 of Set 2 | berlevag
# Processing Record 2 of Set 2 | poum
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | tigre
# Processing Record 6 of Set 2 | pangnirtung
# Processing Record 7 of Set 2 | akyab
# Processing Record 8 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | jiazi
# Processing Record 11 of Set 2 | cody
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | ginir
# Processing Record 17 of Set 2 | jimo
# Processing Record 18 of Set 2 | chokurdakh
# Processing Record 19 of Set 2 | hambantota
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | porto belo
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | rosarito
# Processing Record 25 of Set 2 | ulladulla
# Processing Record 26 of Set 2 | kungurtug
# Processing Record 27 of Set 2 | vaitape
# Processing Record 28 of Set 2 | hofn
# Processing Record 29 of Set 2 | balkanabat
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | ancud
# Processing Record 33 of Set 2 | shakawe
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | pinotepa de don luis
# Processing Record 36 of Set 2 | pandan
# Processing Record 37 of Set 2 | beloha
# Processing Record 38 of Set 2 | port lincoln
# Processing Record 39 of Set 2 | trairi
# Processing Record 40 of Set 2 | saint-leu
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | bronnoysund
# Processing Record 43 of Set 2 | sanchez
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | coihaique
# Processing Record 46 of Set 2 | phenix city
# Processing Record 47 of Set 2 | camopi
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | cherdyn
# Processing Record 50 of Set 2 | mahebourg
# Processing Record 1 of Set 3 | leningradskiy
# Processing Record 2 of Set 3 | san patricio
# Processing Record 3 of Set 3 | cervo
# Processing Record 4 of Set 3 | poyarkovo
# Processing Record 5 of Set 3 | khandyga
# Processing Record 6 of Set 3 | camapua
# Processing Record 7 of Set 3 | camacupa
# Processing Record 8 of Set 3 | taltal
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 3 | kimbe
# Processing Record 12 of Set 3 | lima
# Processing Record 13 of Set 3 | pallasovka
# Processing Record 14 of Set 3 | tilichiki
# Processing Record 15 of Set 3 | saskylakh
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | vao
# Processing Record 18 of Set 3 | sobolevo
# Processing Record 19 of Set 3 | xiamen
# Processing Record 20 of Set 3 | acapulco
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | karpogory
# Processing Record 23 of Set 3 | whyalla
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | antofagasta
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | alice springs
# Processing Record 28 of Set 3 | bushehr
# Processing Record 29 of Set 3 | kuryk
# Processing Record 30 of Set 3 | canutama
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | mehamn
# Processing Record 36 of Set 3 | san martin
# Processing Record 37 of Set 3 | punta arenas
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | rosario do sul
# Processing Record 40 of Set 3 | margate
# Processing Record 41 of Set 3 | hay river
# Processing Record 42 of Set 3 | nalut
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | trelew
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | damara
# Processing Record 47 of Set 3 | laguna
# Processing Record 48 of Set 3 | lahij
# Processing Record 49 of Set 3 | korla
# Processing Record 50 of Set 3 | hamilton
# Processing Record 1 of Set 4 | marathon
# Processing Record 2 of Set 4 | chistogorskiy
# Processing Record 3 of Set 4 | hovd
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | rawson
# Processing Record 6 of Set 4 | puerto berrio
# Processing Record 7 of Set 4 | krasnyy klyuch
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | dengzhou
# Processing Record 10 of Set 4 | baherden
# Processing Record 11 of Set 4 | te anau
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | goderich
# Processing Record 14 of Set 4 | brae
# Processing Record 15 of Set 4 | whakatane
# Processing Record 16 of Set 4 | vanimo
# Processing Record 17 of Set 4 | tessalit
# Processing Record 18 of Set 4 | lasem
# Processing Record 19 of Set 4 | ithaca
# Processing Record 20 of Set 4 | yumen
# Processing Record 21 of Set 4 | sinjar
# Processing Record 22 of Set 4 | byron bay
# Processing Record 23 of Set 4 | gao
# Processing Record 24 of Set 4 | grand gaube
# Processing Record 25 of Set 4 | oranjemund
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | isangel
# Processing Record 28 of Set 4 | ilulissat
# Processing Record 29 of Set 4 | talnakh
# Processing Record 30 of Set 4 | beira
# Processing Record 31 of Set 4 | buala
# Processing Record 32 of Set 4 | fershampenuaz
# Processing Record 33 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 4 | arlit
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | barra patuca
# Processing Record 38 of Set 4 | tatarsk
# Processing Record 39 of Set 4 | homburg
# Processing Record 40 of Set 4 | nhlangano
# Processing Record 41 of Set 4 | amapa
# Processing Record 42 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 4 | cape town
# Processing Record 44 of Set 4 | maltahohe
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | ucluelet
# Processing Record 47 of Set 4 | palembang
# Processing Record 48 of Set 4 | colombo
# Processing Record 49 of Set 4 | bihar
# Processing Record 50 of Set 4 | hobart
# Processing Record 1 of Set 5 | skibbereen
# Processing Record 2 of Set 5 | haines junction
# Processing Record 3 of Set 5 | ganzhou
# Processing Record 4 of Set 5 | chebsara
# Processing Record 5 of Set 5 | strezhevoy
# Processing Record 6 of Set 5 | tual
# Processing Record 7 of Set 5 | marolambo
# Processing Record 8 of Set 5 | aranos
# Processing Record 9 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 5 | troitsk
# Processing Record 11 of Set 5 | kiama
# Processing Record 12 of Set 5 | slave lake
# Processing Record 13 of Set 5 | walvis bay
# Processing Record 14 of Set 5 | straumen
# Processing Record 15 of Set 5 | paka
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | mocuba
# Processing Record 18 of Set 5 | aykhal
# Processing Record 19 of Set 5 | guozhen
# Processing Record 20 of Set 5 | tuatapere
# Processing Record 21 of Set 5 | upernavik
# Processing Record 22 of Set 5 | san jose
# Processing Record 23 of Set 5 | sao joao da barra
# Processing Record 24 of Set 5 | sorland
# Processing Record 25 of Set 5 | teknaf
# Processing Record 26 of Set 5 | pisco
# Processing Record 27 of Set 5 | santa isabel
# Processing Record 28 of Set 5 | jagdispur
# Processing Record 29 of Set 5 | nioro
# Processing Record 30 of Set 5 | nevsehir
# Processing Record 31 of Set 5 | dvinskoy
# Processing Record 32 of Set 5 | hollins
# Processing Record 33 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 5 | sao jose da coroa grande
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | uvira
# Processing Record 37 of Set 5 | churapcha
# Processing Record 38 of Set 5 | yeppoon
# Processing Record 39 of Set 5 | vila franca do campo
# Processing Record 40 of Set 5 | kapit
# Processing Record 41 of Set 5 | semnan
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | kirovskiy
# Processing Record 45 of Set 5 | ugoofaaru
# Processing Record 46 of Set 5 | carballo
# Processing Record 47 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 48 of Set 5 | nizhniy kuranakh
# Processing Record 49 of Set 5 | troitskiy
# Processing Record 50 of Set 5 | onokhoy
# Processing Record 1 of Set 6 | naples
# Processing Record 2 of Set 6 | yenagoa
# Processing Record 3 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 6 | kodiak
# Processing Record 5 of Set 6 | ust-omchug
# Processing Record 6 of Set 6 | iquitos
# Processing Record 7 of Set 6 | union
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | gizo
# Processing Record 10 of Set 6 | sayat
# Processing Record 11 of Set 6 | sao filipe
# Processing Record 12 of Set 6 | chiredzi
# Processing Record 13 of Set 6 | kulu
# Processing Record 14 of Set 6 | paslek
# Processing Record 15 of Set 6 | camacha
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | geraldton
# Processing Record 18 of Set 6 | belmonte
# Processing Record 19 of Set 6 | liberal
# Processing Record 20 of Set 6 | landerneau
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | yabrud
# Processing Record 23 of Set 6 | bristol
# Processing Record 24 of Set 6 | torbay
# Processing Record 25 of Set 6 | aksehir
# Processing Record 26 of Set 6 | ahipara
# Processing Record 27 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 28 of Set 6 | bonfim
# Processing Record 29 of Set 6 | monte alegre
# Processing Record 30 of Set 6 | moroni
# Processing Record 31 of Set 6 | jalu
# Processing Record 32 of Set 6 | seljord
# Processing Record 33 of Set 6 | saint-francois
# Processing Record 34 of Set 6 | lakes entrance
# Processing Record 35 of Set 6 | burnie
# Processing Record 36 of Set 6 | wangaratta
# Processing Record 37 of Set 6 | port moresby
# Processing Record 38 of Set 6 | nynashamn
# Processing Record 39 of Set 6 | westport
# Processing Record 40 of Set 6 | zhigansk
# Processing Record 41 of Set 6 | clyde river
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | lorengau
# Processing Record 44 of Set 6 | saint-pierre
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | sambava
# Processing Record 47 of Set 6 | guerrero negro
# Processing Record 48 of Set 6 | thompson
# Processing Record 49 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 6 | luanda
# Processing Record 1 of Set 7 | wisconsin rapids
# Processing Record 2 of Set 7 | ust-tsilma
# Processing Record 3 of Set 7 | havoysund
# Processing Record 4 of Set 7 | moose factory
# Processing Record 5 of Set 7 | itaberaba
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | asilah
# Processing Record 8 of Set 7 | caruray
# Processing Record 9 of Set 7 | puerto carreno
# Processing Record 10 of Set 7 | santarem
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | plettenberg bay
# Processing Record 13 of Set 7 | pangody
# Processing Record 14 of Set 7 | bilma
# Processing Record 15 of Set 7 | ha tinh
# Processing Record 16 of Set 7 | khuzdar
# Processing Record 17 of Set 7 | rio gallegos
# Processing Record 18 of Set 7 | chicama
# Processing Record 19 of Set 7 | carlagan
# Processing Record 20 of Set 7 | ostrovnoy
# Processing Record 21 of Set 7 | east london
# Processing Record 22 of Set 7 | santa apolonia
# Processing Record 23 of Set 7 | avera
# Processing Record 24 of Set 7 | aitape
# Processing Record 25 of Set 7 | nakhon phanom
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | ixtapa
# Processing Record 28 of Set 7 | tsaratanana
# Processing Record 29 of Set 7 | miram shah
# Processing Record 30 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 31 of Set 7 | karamken
# City not found. Skipping...
# Processing Record 32 of Set 7 | college
# Processing Record 33 of Set 7 | lazaro cardenas
# Processing Record 34 of Set 7 | krasnoselkup
# Processing Record 35 of Set 7 | peniche
# Processing Record 36 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 37 of Set 7 | lerwick
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | yellowknife
# Processing Record 40 of Set 7 | bachaquero
# Processing Record 41 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 42 of Set 7 | mackay
# Processing Record 43 of Set 7 | biak
# Processing Record 44 of Set 7 | mae chan
# Processing Record 45 of Set 7 | volsk
# Processing Record 46 of Set 7 | tarko-sale
# Processing Record 47 of Set 7 | batemans bay
# Processing Record 48 of Set 7 | tura
# Processing Record 49 of Set 7 | te horo
# Processing Record 50 of Set 7 | hondagua
# Processing Record 1 of Set 8 | surt
# Processing Record 2 of Set 8 | suntar
# Processing Record 3 of Set 8 | karratha
# Processing Record 4 of Set 8 | gamba
# Processing Record 5 of Set 8 | codrington
# Processing Record 6 of Set 8 | paamiut
# Processing Record 7 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 8 of Set 8 | qasigiannguit
# Processing Record 9 of Set 8 | randvere
# City not found. Skipping...
# Processing Record 10 of Set 8 | sfantu gheorghe
# Processing Record 11 of Set 8 | namibe
# Processing Record 12 of Set 8 | mokrous
# Processing Record 13 of Set 8 | soeng sang
# Processing Record 14 of Set 8 | loukhi
# Processing Record 15 of Set 8 | bereda
# Processing Record 16 of Set 8 | cabinda
# Processing Record 17 of Set 8 | mixtepec
# City not found. Skipping...
# Processing Record 18 of Set 8 | chumikan
# Processing Record 19 of Set 8 | beaverlodge
# Processing Record 20 of Set 8 | pafos
# Processing Record 21 of Set 8 | metz
# Processing Record 22 of Set 8 | joshimath
# Processing Record 23 of Set 8 | amga
# Processing Record 24 of Set 8 | rawlins
# Processing Record 25 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 8 | zhaodong
# Processing Record 27 of Set 8 | takoradi
# Processing Record 28 of Set 8 | zaysan
# Processing Record 29 of Set 8 | flin flon
# Processing Record 30 of Set 8 | samarai
# Processing Record 31 of Set 8 | san cristobal
# Processing Record 32 of Set 8 | rio grande
# Processing Record 33 of Set 8 | coos bay
# Processing Record 34 of Set 8 | bandarban
# Processing Record 35 of Set 8 | bath
# Processing Record 36 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 37 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 8 | iralaya
# Processing Record 39 of Set 8 | hualmay
# Processing Record 40 of Set 8 | sur
# Processing Record 41 of Set 8 | pevek
# Processing Record 42 of Set 8 | kaohsiung
# Processing Record 43 of Set 8 | kuching
# Processing Record 44 of Set 8 | esperance
# Processing Record 45 of Set 8 | sibolga
# Processing Record 46 of Set 8 | zhangye
# Processing Record 47 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 8 | killybegs
# Processing Record 49 of Set 8 | carutapera
# Processing Record 50 of Set 8 | sargatskoye
# Processing Record 1 of Set 9 | aswan
# Processing Record 2 of Set 9 | wajir
# Processing Record 3 of Set 9 | turbat
# Processing Record 4 of Set 9 | zharkent
# Processing Record 5 of Set 9 | bowling green
# Processing Record 6 of Set 9 | broken hill
# Processing Record 7 of Set 9 | kushima
# Processing Record 8 of Set 9 | young
# Processing Record 9 of Set 9 | charters towers
# Processing Record 10 of Set 9 | spanish town
# Processing Record 11 of Set 9 | feni
# Processing Record 12 of Set 9 | the valley
# Processing Record 13 of Set 9 | olafsvik
# Processing Record 14 of Set 9 | malindi
# Processing Record 15 of Set 9 | pinega
# Processing Record 16 of Set 9 | roald
# Processing Record 17 of Set 9 | lhokseumawe
# Processing Record 18 of Set 9 | iskateley
# Processing Record 19 of Set 9 | las varas
# Processing Record 20 of Set 9 | along
# Processing Record 21 of Set 9 | krasnyy yar
# Processing Record 22 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 9 | bucerias
# Processing Record 24 of Set 9 | nemuro
# Processing Record 25 of Set 9 | galashki
# Processing Record 26 of Set 9 | ouro preto do oeste
# Processing Record 27 of Set 9 | beringovskiy
# Processing Record 28 of Set 9 | taitung
# Processing Record 29 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | yar-sale
# Processing Record 32 of Set 9 | ponta delgada
# Processing Record 33 of Set 9 | abeche
# Processing Record 34 of Set 9 | baykit
# Processing Record 35 of Set 9 | tazovskiy
# Processing Record 36 of Set 9 | coahuayana
# Processing Record 37 of Set 9 | mikhaylovsk
# Processing Record 38 of Set 9 | staryy nadym
# Processing Record 39 of Set 9 | buchanan
# Processing Record 40 of Set 9 | kaitangata
# Processing Record 41 of Set 9 | zwedru
# Processing Record 42 of Set 9 | murgab
# Processing Record 43 of Set 9 | mount gambier
# Processing Record 44 of Set 9 | abu samrah
# Processing Record 45 of Set 9 | feltre
# Processing Record 46 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 9 | camotan
# Processing Record 48 of Set 9 | huancavelica
# Processing Record 49 of Set 9 | saquena
# Processing Record 50 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 10 | salalah
# Processing Record 2 of Set 10 | seddon
# Processing Record 3 of Set 10 | mangrol
# Processing Record 4 of Set 10 | senno
# Processing Record 5 of Set 10 | santa cruz
# Processing Record 6 of Set 10 | dongsheng
# Processing Record 7 of Set 10 | bitung
# Processing Record 8 of Set 10 | jinchang
# Processing Record 9 of Set 10 | mount isa
# Processing Record 10 of Set 10 | dourbali
# Processing Record 11 of Set 10 | boma
# Processing Record 12 of Set 10 | adeje
# Processing Record 13 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 10 | zasechnoye
# Processing Record 15 of Set 10 | bulungu
# Processing Record 16 of Set 10 | la ronge
# Processing Record 17 of Set 10 | bouna
# Processing Record 18 of Set 10 | archidona
# Processing Record 19 of Set 10 | youkounkoun
# Processing Record 20 of Set 10 | mecca
# Processing Record 21 of Set 10 | cleveland
# Processing Record 22 of Set 10 | novikovo
# Processing Record 23 of Set 10 | lata
# Processing Record 24 of Set 10 | kadaya
# Processing Record 25 of Set 10 | nizhniy tsasuchey
# Processing Record 26 of Set 10 | ust-nera
# Processing Record 27 of Set 10 | havelock
# Processing Record 28 of Set 10 | asau
# Processing Record 29 of Set 10 | luderitz
# Processing Record 30 of Set 10 | volovo
# Processing Record 31 of Set 10 | vostok
# Processing Record 32 of Set 10 | iberia
# Processing Record 33 of Set 10 | astrakhan
# Processing Record 34 of Set 10 | alofi
# Processing Record 35 of Set 10 | morshansk
# Processing Record 36 of Set 10 | oxapampa
# Processing Record 37 of Set 10 | wanning
# Processing Record 38 of Set 10 | nenjiang
# Processing Record 39 of Set 10 | dong xoai
# Processing Record 40 of Set 10 | winnemucca
# Processing Record 41 of Set 10 | la asuncion
# Processing Record 42 of Set 10 | khasan
# Processing Record 43 of Set 10 | finschhafen
# Processing Record 44 of Set 10 | kashi
# Processing Record 45 of Set 10 | kuytun
# Processing Record 46 of Set 10 | diamantino
# Processing Record 47 of Set 10 | malinyi
# Processing Record 48 of Set 10 | dalvik
# Processing Record 49 of Set 10 | sjenica
# Processing Record 50 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 11 | chapais
# Processing Record 2 of Set 11 | jaguarari
# Processing Record 3 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 11 | kingseat
# Processing Record 5 of Set 11 | isiolo
# Processing Record 6 of Set 11 | shubarkuduk
# Processing Record 7 of Set 11 | meaford
# Processing Record 8 of Set 11 | erenhot
# Processing Record 9 of Set 11 | jambi
# Processing Record 10 of Set 11 | dingzhou
# Processing Record 11 of Set 11 | kieta
# Processing Record 12 of Set 11 | aksha
# Processing Record 13 of Set 11 | mahon
# Processing Record 14 of Set 11 | sola
# Processing Record 15 of Set 11 | makakilo city
# Processing Record 16 of Set 11 | palmares
# Processing Record 17 of Set 11 | longavi
# Processing Record 18 of Set 11 | straseni
# Processing Record 19 of Set 11 | pringsewu
# Processing Record 20 of Set 11 | kaeo
# Processing Record 21 of Set 11 | cayenne
# Processing Record 22 of Set 11 | quelimane
# Processing Record 23 of Set 11 | arani
# Processing Record 24 of Set 11 | kaniama
# Processing Record 25 of Set 11 | qandala
# Processing Record 26 of Set 11 | nicoya
# Processing Record 27 of Set 11 | hagavik
# Processing Record 28 of Set 11 | ballina
# Processing Record 29 of Set 11 | hirado
# Processing Record 30 of Set 11 | fairbanks
# Processing Record 31 of Set 11 | san ramon
# Processing Record 32 of Set 11 | belle fourche
# Processing Record 33 of Set 11 | drayton valley
# Processing Record 34 of Set 11 | qui nhon
# Processing Record 35 of Set 11 | richards bay
# Processing Record 36 of Set 11 | chunskiy
# Processing Record 37 of Set 11 | maumere
# Processing Record 38 of Set 11 | bichura
# Processing Record 39 of Set 11 | klyuchi
# Processing Record 40 of Set 11 | turukhansk
# Processing Record 41 of Set 11 | huaihua
# Processing Record 42 of Set 11 | mithimna
# City not found. Skipping...
# Processing Record 43 of Set 11 | tucuman
# Processing Record 44 of Set 11 | rocha
# Processing Record 45 of Set 11 | rock sound
# Processing Record 46 of Set 11 | limbuhan
# Processing Record 47 of Set 11 | hasaki
# Processing Record 48 of Set 11 | nizwa
# Processing Record 49 of Set 11 | grindavik
# Processing Record 50 of Set 11 | arman
# Processing Record 1 of Set 12 | kunming
# Processing Record 2 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 12 | port blair
# Processing Record 4 of Set 12 | aljustrel
# Processing Record 5 of Set 12 | maceio
# Processing Record 6 of Set 12 | bathsheba
# Processing Record 7 of Set 12 | blagoyevo
# Processing Record 8 of Set 12 | acultzingo
# Processing Record 9 of Set 12 | svetlogorsk
# Processing Record 10 of Set 12 | namatanai
# Processing Record 11 of Set 12 | zanjan
# Processing Record 12 of Set 12 | new ulm
# Processing Record 13 of Set 12 | palana
# Processing Record 14 of Set 12 | dwarka
# Processing Record 15 of Set 12 | benguela
# Processing Record 16 of Set 12 | nybro
# Processing Record 17 of Set 12 | kenai
# Processing Record 18 of Set 12 | moron
# Processing Record 19 of Set 12 | great bend
# Processing Record 20 of Set 12 | darnah
# Processing Record 21 of Set 12 | emmett
# Processing Record 22 of Set 12 | hirtshals
# Processing Record 23 of Set 12 | katherine
# Processing Record 24 of Set 12 | mareeba
# Processing Record 25 of Set 12 | tabuk
# Processing Record 26 of Set 12 | beyneu
# Processing Record 27 of Set 12 | conakry
# Processing Record 28 of Set 12 | ochamchira
# Processing Record 29 of Set 12 | uni
# Processing Record 30 of Set 12 | zaozerne
# Processing Record 31 of Set 12 | vilyuysk
# Processing Record 32 of Set 12 | kurumkan
# Processing Record 33 of Set 12 | key west
# Processing Record 34 of Set 12 | mikuni
# Processing Record 35 of Set 12 | chekhov
# Processing Record 36 of Set 12 | kendari
# Processing Record 37 of Set 12 | kulhudhuffushi
# Processing Record 38 of Set 12 | port shepstone
# Processing Record 39 of Set 12 | bonthe
# Processing Record 40 of Set 12 | sept-iles
# Processing Record 41 of Set 12 | el carmen
# Processing Record 42 of Set 12 | kamina
# Processing Record 43 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 12 | cheremukhovo
# Processing Record 45 of Set 12 | svetlyy
# Processing Record 46 of Set 12 | vallenar
# Processing Record 47 of Set 12 | kasongo-lunda
# Processing Record 48 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 49 of Set 12 | necochea
# Processing Record 50 of Set 12 | yarada
# Processing Record 1 of Set 13 | shimoda
# Processing Record 2 of Set 13 | entre rios
# Processing Record 3 of Set 13 | madang
# Processing Record 4 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 13 | high prairie
# Processing Record 6 of Set 13 | kodinsk
# Processing Record 7 of Set 13 | cap malheureux
# Processing Record 8 of Set 13 | olga
# Processing Record 9 of Set 13 | hastings
# Processing Record 10 of Set 13 | san pedro
# Processing Record 11 of Set 13 | gat
# Processing Record 12 of Set 13 | lambarene
# Processing Record 13 of Set 13 | grand island
# Processing Record 14 of Set 13 | tirumullaivasal
# Processing Record 15 of Set 13 | rosetta
# Processing Record 16 of Set 13 | longyearbyen
# Processing Record 17 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 13 | corinto
# Processing Record 19 of Set 13 | grafton
# Processing Record 20 of Set 13 | cobija
# Processing Record 21 of Set 13 | bar harbor
# Processing Record 22 of Set 13 | fernandez
# Processing Record 23 of Set 13 | dingle
# Processing Record 24 of Set 13 | mulchen
# Processing Record 25 of Set 13 | bodden town
# Processing Record 26 of Set 13 | ossora
# Processing Record 27 of Set 13 | itoman
# Processing Record 28 of Set 13 | bayamo
# Processing Record 29 of Set 13 | seoul
# Processing Record 30 of Set 13 | port macquarie
# Processing Record 31 of Set 13 | ambilobe
# Processing Record 32 of Set 13 | zhanaozen
# Processing Record 33 of Set 13 | falkenberg
# Processing Record 34 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 13 | northam
# Processing Record 36 of Set 13 | lawton
# Processing Record 37 of Set 13 | swift current
# Processing Record 38 of Set 13 | isiro
# Processing Record 39 of Set 13 | umm lajj
# Processing Record 40 of Set 13 | neiafu
# Processing Record 41 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 13 | hobyo
# Processing Record 43 of Set 13 | zyryanka
# Processing Record 44 of Set 13 | darhan
# Processing Record 45 of Set 13 | azul
# Processing Record 46 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 13 | tutoia
# Processing Record 48 of Set 13 | sitka
# Processing Record 49 of Set 13 | isla vista
# Processing Record 50 of Set 13 | altus
# Processing Record 1 of Set 14 | caravelas
# Processing Record 2 of Set 14 | ziro
# Processing Record 3 of Set 14 | shingu
# Processing Record 4 of Set 14 | mahina
# Processing Record 5 of Set 14 | yarega
# Processing Record 6 of Set 14 | zurrieq
# Processing Record 7 of Set 14 | kalakamati
# Processing Record 8 of Set 14 | saint-georges
# Processing Record 9 of Set 14 | santa rosa
# Processing Record 10 of Set 14 | meulaboh
# Processing Record 11 of Set 14 | kollam
# Processing Record 12 of Set 14 | nantucket
# Processing Record 13 of Set 14 | takhtamygda
# Processing Record 14 of Set 14 | jumla
# Processing Record 15 of Set 14 | ust-kuyga
# Processing Record 16 of Set 14 | dzerzhinsk
# Processing Record 17 of Set 14 | sterling
# Processing Record 18 of Set 14 | kostroma
# Processing Record 19 of Set 14 | rudnyy
# Processing Record 20 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 21 of Set 14 | carmen
# Processing Record 22 of Set 14 | majholi
# Processing Record 23 of Set 14 | cognac
# Processing Record 24 of Set 14 | kumo
# Processing Record 25 of Set 14 | naze
# Processing Record 26 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 14 | matadi
# Processing Record 28 of Set 14 | desaguadero
# Processing Record 29 of Set 14 | ca mau
# Processing Record 30 of Set 14 | broome
# Processing Record 31 of Set 14 | santa isabel do rio negro
# Processing Record 32 of Set 14 | parakai
# Processing Record 33 of Set 14 | reading
# Processing Record 34 of Set 14 | poltavka
# Processing Record 35 of Set 14 | mezen
# Processing Record 36 of Set 14 | moa
# Processing Record 37 of Set 14 | roebourne
# Processing Record 38 of Set 14 | boyle
# Processing Record 39 of Set 14 | changqing
# Processing Record 40 of Set 14 | leshukonskoye
# Processing Record 41 of Set 14 | russell
# Processing Record 42 of Set 14 | abha
# Processing Record 43 of Set 14 | banda aceh
# Processing Record 44 of Set 14 | virginia beach
# Processing Record 45 of Set 14 | katha
# City not found. Skipping...
# Processing Record 46 of Set 14 | freeport
# Processing Record 47 of Set 14 | bonham
# Processing Record 48 of Set 14 | khonsar
# City not found. Skipping...
# Processing Record 49 of Set 14 | carlos chagas
# Processing Record 50 of Set 14 | dovers
# Processing Record 1 of Set 15 | aksu
# Processing Record 2 of Set 15 | viedma
# Processing Record 3 of Set 15 | wum
# Processing Record 4 of Set 15 | imphal
# Processing Record 5 of Set 15 | mega
# Processing Record 6 of Set 15 | tallahassee
# Processing Record 7 of Set 15 | gallup
# Processing Record 8 of Set 15 | pangkalanbuun
# Processing Record 9 of Set 15 | le vauclin
# Processing Record 10 of Set 15 | liwale
# Processing Record 11 of Set 15 | shenjiamen
# Processing Record 12 of Set 15 | heihe
# Processing Record 13 of Set 15 | san agustin
# Processing Record 14 of Set 15 | cap-aux-meules
# Processing Record 15 of Set 15 | sweetwater
# Processing Record 16 of Set 15 | saint-denis
# Processing Record 17 of Set 15 | bose
# Processing Record 18 of Set 15 | hyeres
# Processing Record 19 of Set 15 | dzhebariki-khaya
# Processing Record 20 of Set 15 | salym
# Processing Record 21 of Set 15 | tommot
# Processing Record 22 of Set 15 | luau
# Processing Record 23 of Set 15 | la victoria
# Processing Record 24 of Set 15 | aviles
# Processing Record 25 of Set 15 | wewak
# Processing Record 26 of Set 15 | jaciara
# Processing Record 27 of Set 15 | torzhok
# Processing Record 28 of Set 15 | upington
# Processing Record 29 of Set 15 | adrar
# Processing Record 30 of Set 15 | umea
# Processing Record 31 of Set 15 | matay
# Processing Record 32 of Set 15 | arroio grande
# Processing Record 33 of Set 15 | le pont-de-claix
# Processing Record 34 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 15 | nouakchott
# Processing Record 36 of Set 15 | mpraeso
# Processing Record 37 of Set 15 | ekhabi
# Processing Record 38 of Set 15 | porto novo
# Processing Record 39 of Set 15 | joutseno
# Processing Record 40 of Set 15 | markha
# Processing Record 41 of Set 15 | arawa
# Processing Record 42 of Set 15 | smithers
# Processing Record 43 of Set 15 | high rock
# Processing Record 44 of Set 15 | maarianhamina
# Processing Record 45 of Set 15 | taixing
# Processing Record 46 of Set 15 | erbach
# Processing Record 47 of Set 15 | golden
# Processing Record 48 of Set 15 | ahuimanu
# Processing Record 49 of Set 15 | hami
# Processing Record 50 of Set 15 | lyubinskiy
# Processing Record 1 of Set 16 | tautira
# Processing Record 2 of Set 16 | maynooth
# Processing Record 3 of Set 16 | tak
# Processing Record 4 of Set 16 | eureka
# Processing Record 5 of Set 16 | ewa beach
# Processing Record 6 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 16 | changping
# Processing Record 8 of Set 16 | keflavik
# Processing Record 9 of Set 16 | nogent-le-rotrou
# Processing Record 10 of Set 16 | waipawa
# Processing Record 11 of Set 16 | livingston
# Processing Record 12 of Set 16 | kanye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 713

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany  42.6001  -73.9662     41.41        65          15
# 1     Manokwari  -0.8667  134.0833     78.84        83         100
# 2       Iqaluit  63.7506  -68.5145     15.53        66          75
# 3      Hermanus -34.4187   19.2345     57.67        69          40
# 4       Rikitea -23.1203 -134.9692     74.91        77           7
# 5      Tasiilaq  65.6145  -37.6368     31.14        96         100
# 6  Puerto Ayora  -0.7393  -90.3518     69.55        94          60
# 7        Satana  20.5833   74.2000     68.18        54          98
# 8     Busselton -33.6500  115.3333     67.60        57          70
# 9          Atar  20.5169  -13.0499     64.22        23           0
#
#    Wind Speed Country Current Description
# 0        1.01      US          few clouds
# 1        2.46      ID     overcast clouds
# 2       13.80      CA          light snow
# 3        4.83      ZA    scattered clouds
# 4       12.75      PF           clear sky
# 5       10.54      GL                snow
# 6        4.00      EC       broken clouds
# 7        3.11      IN     overcast clouds
# 8       15.64      AU       broken clouds
# 9        3.91      MR           clear sky

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany  42.6001  -73.9662     41.41        65          15
# 1     Manokwari  -0.8667  134.0833     78.84        83         100
# 2       Iqaluit  63.7506  -68.5145     15.53        66          75
# 3      Hermanus -34.4187   19.2345     57.67        69          40
# 4       Rikitea -23.1203 -134.9692     74.91        77           7
# 5      Tasiilaq  65.6145  -37.6368     31.14        96         100
# 6  Puerto Ayora  -0.7393  -90.3518     69.55        94          60
# 7        Satana  20.5833   74.2000     68.18        54          98
# 8     Busselton -33.6500  115.3333     67.60        57          70
# 9          Atar  20.5169  -13.0499     64.22        23           0
#
#    Wind Speed Country Current Description
# 0        1.01      US          few clouds
# 1        2.46      ID     overcast clouds
# 2       13.80      CA          light snow
# 3        4.83      ZA    scattered clouds
# 4       12.75      PF           clear sky
# 5       10.54      GL                snow
# 6        4.00      EC       broken clouds
# 7        3.11      IN     overcast clouds
# 8       15.64      AU       broken clouds
# 9        3.91      MR           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city = city_data_df["City"]
country = city_data_df["Country"]
lats = city_data_df["Lat"]
lngs = city_data_df["Lng"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
description = city_data_df["Current Description"]

# Recreate the DataFrame by using the new column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Display sample data
city_data_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Albany  42.6001  -73.9662     41.41        65          15
# 1           Manokwari  -0.8667  134.0833     78.84        83         100
# 2             Iqaluit  63.7506  -68.5145     15.53        66          75
# 3            Hermanus -34.4187   19.2345     57.67        69          40
# 4             Rikitea -23.1203 -134.9692     74.91        77           7
# ..                ...      ...       ...       ...       ...         ...
# 708          Keflavik  64.0049  -22.5624     36.03       100          75
# 709  Nogent-Le-Rotrou  48.3333    1.0000     33.66        94          17
# 710           Waipawa -41.4122  175.5153     66.88        52          10
# 711        Livingston  55.9029   -3.5226     37.80        91          97
# 712             Kanye -24.9667   25.3327     69.13        28           0
#
#      Wind Speed Country Current Description
# 0          1.01      US          few clouds
# 1          2.46      ID     overcast clouds
# 2         13.80      CA          light snow
# 3          4.83      ZA    scattered clouds
# 4         12.75      PF           clear sky
# ..          ...     ...                 ...
# 708        5.75      IS       broken clouds
# 709       11.61      FR          few clouds
# 710        0.85      NZ           clear sky
# 711        8.52      GB     overcast clouds
# 712        6.11      BW           clear sky
#
# [713 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
